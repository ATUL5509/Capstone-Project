# %%
import pandas as pd

# %%
emp = {'Name':['Kapil', 'Rohit', 'Sumit', 'Mohit', 'Ajay', 'Manjul'],
       'ID':[201, 201, 202, 203, 204, 205],
       'City': ['Uttar Pradesh', 'Nodia', 'Aligarh', 'Bengaluru', 'Faridabad', 'Delhi']}
df = pd.DataFrame(emp)
df
# Out:
#      Name   ID           City
# 0   Kapil  201  Uttar Pradesh
# 1   Rohit  201          Nodia
# 2   Sumit  202        Aligarh
# 3   Mohit  203      Bengaluru
# 4    Ajay  204      Faridabad
# 5  Manjul  205          Delhi

# %%
df['Name']
# Out:
# 0     Kapil
# 1     Rohit
# 2     Sumit
# 3     Mohit
# 4      Ajay
# 5    Manjul
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df.Name
# Out:
# 0     Kapil
# 1     Rohit
# 2     Sumit
# 3     Mohit
# 4      Ajay
# 5    Manjul
# Name: Name, dtype: object

# %%
type(df.Name)
# Out:
# pandas.core.series.Series

# %%
df[['Name']]
# Out:
#      Name
# 0   Kapil
# 1   Rohit
# 2   Sumit
# 3   Mohit
# 4    Ajay
# 5  Manjul

# %%
type(df[['Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      Name   ID           City
# 0   Kapil  201  Uttar Pradesh
# 1   Rohit  201          Nodia
# 2   Sumit  202        Aligarh
# 3   Mohit  203      Bengaluru
# 4    Ajay  204      Faridabad
# 5  Manjul  205          Delhi

# %%
df[['Name','City']]
# Out:
#      Name           City
# 0   Kapil  Uttar Pradesh
# 1   Rohit          Nodia
# 2   Sumit        Aligarh
# 3   Mohit      Bengaluru
# 4    Ajay      Faridabad
# 5  Manjul          Delhi

# %%
df
# Out:
#      Name   ID           City
# 0   Kapil  201  Uttar Pradesh
# 1   Rohit  201          Nodia
# 2   Sumit  202        Aligarh
# 3   Mohit  203      Bengaluru
# 4    Ajay  204      Faridabad
# 5  Manjul  205          Delhi

# %%
df.iloc[1:5, 0::2]
# Out:
#     Name       City
# 1  Rohit      Nodia
# 2  Sumit    Aligarh
# 3  Mohit  Bengaluru
# 4   Ajay  Faridabad

# %%
df.iloc[1:5][['Name','City']]
# Out:
#     Name       City
# 1  Rohit      Nodia
# 2  Sumit    Aligarh
# 3  Mohit  Bengaluru
# 4   Ajay  Faridabad

# %%
df = pd.read_csv('Titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv(r"C:\Users\Katul\Downloads\Titanic.xls")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv(r"C:\Users\Katul\Downloads\Titanic.xls")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Katul\Downloads\Titanic.xls")
df.head()
