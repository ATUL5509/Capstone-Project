# %% [markdown]
# # Assignment

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt


y_tune = [0, 1, 1, 0, 1, 0, 1, 0]
y_pred = [0, 1, 1, 0, 1, 1, 1, 0]

cm = confusion_matrix(y_tune, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Class 0', 'Class 1'])
disp.plot(cmap='Blues')
plt.title('Cinfusion Matrix')
plt.show()

# %% [markdown]
# # 2. ROC Curve, AUC, precision, recall etc

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_score, recall_score
import numpy as np

y_tune = [0, 1, 1, 0, 1, 0, 1, 0]
y_scores = np.array([0.1, 0.4, 0.35, 0.8, 0.7, 0.3, 0.6, 0.2])


fpr, tpr, thresholds = roc_curve(y_tune, y_scores)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()


y_pred_binary = np.array([0, 1, 1, 1, 1, 0, 1, 0])  # Example binary predictions
precision = precision_score(y_true, y_pred_binary)
recall = recall_score(y_true, y_pred_binary)

print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 25
#      21 plt.show()
#      24 y_pred_binary = np.array([0, 1, 1, 1, 1, 0, 1, 0])  # Example binary predictions
# ---> 25 precision = precision_score(y_true, y_pred_binary)
#      26 recall = recall_score(y_true, y_pred_binary)
#      28 print(f'Precision: {precision:.2f}')
#
# NameError: name 'y_true' is not defined

# %% [markdown]
# # 3. Heatmap of Correlation Matrix

# %%
data = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [5, 4, 3, 2, 1],
    'C': [2, 3, 4, 5, 7]
})

corr = data.corr()


plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # 4. DecisionTreeRegressor to Predict Insurance Premium

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error


X = pd.DataFrame({
    'Age': [25, 30, 45, 50, 55],
    'Vehicle_Type': [1, 2, 2, 1, 1]
})
y = np.array([1000, 1500, 2000, 1800, 1600])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

regressor = DecisionTreeRegressor(criterion='squared_error')
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
mse = mean_squared_error(y_test, y_pred)

print(f'Mean Squared Error: {mse:.2f}')
# Out:
# Mean Squared Error: 40000.00
